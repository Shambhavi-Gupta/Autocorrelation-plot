# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhavi-Gupta/Autocorrelation-plot/blob/master/Autocorrelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize = (16,6), dpi = 80)

# plot the data using the built in plots from the stats module
plot_acf(df["Radiation"], ax = ax1, lags = 50)
plot_pacf(df["Humidity"], ax = ax2, lags = 15);
plt.savefig('plot.png')
